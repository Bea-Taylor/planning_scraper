# %% [markdown]
# ## Example implementation

# %%
import pandas as pd

import sys
sys.path.append('pipeline')
from planning_scraper import PlanningScraper

# %%
council_example = 'newham' 
postcode = 'E13 0AG'

# %%
url_df = pd.read_csv("data/input/example_urls.csv")
url_df[url_df["council"] == council_example]["url"].values[0]
# Out:
# 'https://pa.newham.gov.uk/online-applications '

# %%
urls = PlanningScraper.get_postcode_page(council=council_example, postcode=postcode)
# Out:
# Searched for postcode: E13 0AG.
# Found URL address

# %%
details = PlanningScraper.scrape_app_details(urls)

# %%
# trun details into a df 
details_df = pd.DataFrame(details)

# %%
details_df
# Out:
#          reference                                                url  \
# 0     23/01098/FUL  https://pa.newham.gov.uk/online-applications/a...
# 1     18/02826/CLE  https://pa.newham.gov.uk/online-applications/a...
# 2     18/00696/LA3  https://pa.newham.gov.uk/online-applications/a...
# 3     16/01386/CLP  https://pa.newham.gov.uk/online-applications/a...
# 4     15/00593/AOD  https://pa.newham.gov.uk/online-applications/a...
# 5     14/02843/AOD  https://pa.newham.gov.uk/online-applications/a...
# 6     14/01997/LA3  https://pa.newham.gov.uk/online-applications/a...
# 7  14/01925/PREDEM  https://pa.newham.gov.uk/online-applications/a...
# 8     14/01273/LA3  https://pa.newham.gov.uk/online-applications/a...
# 9     13/00386/LA3  https://pa.newham.gov.uk/online-applications/a...
#
#     date_validated                                            address  \
# 0  Fri 16 Jun 2023  Curwen Primary School Atlas Road Plaistow Lond...
# 1  Thu 04 Oct 2018              11 Atlas Road Plaistow London E13 0AG
# 2  Wed 14 Mar 2018  Curwen Primary School Atlas Road Plaistow Lond...
# 3  Tue 24 May 2016               5 Atlas Road Plaistow London E13 0AG
# 4  Mon 16 Mar 2015  Curwen Junior And Infants School Atlas Road Pl...
# 5  Thu 18 Dec 2014  Curwen Junior And Infants School Atlas Road Pl...
# 6  Fri 29 Aug 2014  Curwen Junior And Infants School Atlas Road Pl...
# 7  Tue 26 Aug 2014  Curwen Junior And Infants School Atlas Road Pl...
# 8  Fri 13 Jun 2014  Curwen Junior And Infants School Atlas Road Pl...
# 9  Mon 11 Mar 2013  Curwen Junior And Infants School Atlas Road Pl...
#
#                                          description  \
# 0  Proposed erection of a single storey timber ga...
# 1  Certificate of lawfulness for the existing use...
# 2  Installation of external canopy to match canop...
# 3              Proposed single storey rear extension
# 4  Approval of details pursuant to Condition 9 (D...
# 5  Approval of details pursuant to Condition 4 (C...
# 6  Expansion of existing School from a 3 Form Ent...
# 7  Application for prior approval for the demolit...
# 8  Provision of modular prefabricated single-stor...
# 9  Erection of a single storey extension to creat...
#
#                       decision    decision_date
# 0                      Approve  Fri 25 Aug 2023
# 1                      Approve  Thu 29 Nov 2018
# 2                      Approve  Tue 17 Apr 2018
# 3                       Refuse  Tue 19 Jul 2016
# 4                      Approve  Fri 10 Jul 2015
# 5                      Approve  Thu 29 Jan 2015
# 6                      Approve  Thu 23 Oct 2014
# 7  Prior Approval Not Required  Thu 18 Sep 2014
# 8                      Approve  Fri 08 Aug 2014
# 9                      Approve  Tue 07 May 2013
