# %% [markdown]
# ## Example implementation

# %%
import pandas as pd

import sys
sys.path.append('pipeline')
from planning_scraper import PlanningScraper

# %%
council_example = 'newham' 
postcode = 'E13 0AG'

# %%
url_df = pd.read_csv("data/input/example_urls.csv")
url_df[url_df["council"] == council_example]["url"].values[0]
# Out:
# 'https://pa.newham.gov.uk/online-applications '

# %%
urls = PlanningScraper.get_postcode_page(council=council_example, postcode=postcode)
# Out:
# Searched for postcode: E13 0AG
# Collected 10 links (total: 10)
# Collected 10 links (total: 20)
# Collected 1 links (total: 21)

# %%
# details = PlanningScraper.scrape_app_details(urls)

# %%
# further_details = PlanningScraper.scrape_app_further_info(urls)

# %%
# # trun details into a df 
# details_df = pd.DataFrame(details)

# %%
    # def scrape_app_details(urls):
    #     """
    #     Scrape planning application details for a list of URLs.
    #     Returns a dict keyed by reference number.
    #     """

    #     service, options = PlanningScraper.driver_options()
    #     driver = webdriver.Chrome(service=service, options=options)

    #     data = {
    #         "reference": [],
    #         "url": [],
    #         "date_validated": [],
    #         "address": [],
    #         "description": [],
    #         "decision": [],
    #         "decision_date": []
    #     }

    #     for url in urls:
    #         driver.get(url)

    #         reference = PlanningScraper.get_table_value(driver, "Reference")
    #         if not reference:
    #             continue

    #         data["reference"].append(reference)
    #         data["url"].append(url)
    #         data["date_validated"].append(
    #             PlanningScraper.get_table_value(driver, "Application Validated")
    #         )
    #         data["address"].append(
    #             PlanningScraper.get_table_value(driver, "Address")
    #         )
    #         data["description"].append(
    #             PlanningScraper.get_table_value(driver, "Proposal")
    #         )
    #         data["decision"].append(
    #             PlanningScraper.get_table_value(driver, "Decision")
    #         )
    #         data["decision_date"].append(
    #             PlanningScraper.get_table_value(driver, "Decision Issued Date")
    #         )

    #         time.sleep(random.uniform(1.5, 3.0))

    #     driver.quit()
    #     return data

# %%
# further_details_df = pd.DataFrame(further_details)

# %%
# further_details_df

# %%
data = PlanningScraper.scrape_app_details(urls)
# Out:
# Scraping URL 1 of 21: https://pa.newham.gov.uk/online-applications/applicationDetails.do?keyVal=RUWLR0JY5W100&activeTab=summary
#   Attempt 1/3
#   Scraped main page for 23/01098/FUL
#   Scraped further info page for 23/01098/FUL
# Scraping URL 2 of 21: https://pa.newham.gov.uk/online-applications/applicationDetails.do?keyVal=PG2H3PJYFW400&activeTab=summary
#   Attempt 1/3
#   Scraped main page for 18/02826/CLE
#   Scraped further info page for 18/02826/CLE
# Scraping URL 3 of 21: https://pa.newham.gov.uk/online-applications/applicationDetails.do?keyVal=P5LC4HJY52R00&activeTab=summary
#   Attempt 1/3
#   Scraped main page for 18/00696/LA3
#   Scraped further info page for 18/00696/LA3
# Scraping URL 4 of 21: https://pa.newham.gov.uk/online-applications/applicationDetails.do?keyVal=O6WQ4PJY0AL00&activeTab=summary
#   Attempt 1/3
#   Scraped main page for 16/01386/CLP
#   Scraped further info page for 16/01386/CLP
# Scraping URL 5 of 21: https://pa.newham.gov.uk/online-applications/applicationDetails.do?keyVal=NKSHIJJYJX000&activeTab=summary
#   Attempt 1/3
#   Scraped main page for 15/00593/AOD
#   Scraped further info page for 15/00593/AOD
# Scraping URL 6 of 21: https://pa.newham.gov.uk/online-applications/applicationDetails.do?keyVal=NFSGSRJYJX000&activeTab=summary
#   Attempt 1/3
#   Scraped main page for 14/02843/AOD
#   Scraped further info page for 14/02843/AOD
# Scraping URL 7 of 21: https://pa.newham.gov.uk/online-applications/applicationDetails.do?keyVal=NB2SR3JYJX000&activeTab=summary
#   Attempt 1/3
#   Attempt 1 failed: Reference missing
#   Attempt 2/3
#   Attempt 2 failed: Reference missing
#   Attempt 3/3
#   Attempt 3 failed: Reference missing
#   All retries failed for https://pa.newham.gov.uk/online-applications/applicationDetails.do?keyVal=NB2SR3JYJX000&activeTab=summary, recording NaNs
# Scraping URL 8 of 21: https://pa.newham.gov.uk/online-applications/applicationDetails.do?keyVal=NAPFJPJY13E00&activeTab=summary
#   Attempt 1/3
#   Attempt 1 failed: Reference missing
#   Attempt 2/3
#   Attempt 2 failed: Reference missing
#   Attempt 3/3
#   Attempt 3 failed: Reference missing
#   All retries failed for https://pa.newham.gov.uk/online-applications/applicationDetails.do?keyVal=NAPFJPJY13E00&activeTab=summary, recording NaNs
# Scraping URL 9 of 21: https://pa.newham.gov.uk/online-applications/applicationDetails.do?keyVal=N7478UJYJX000&activeTab=summary
#   Attempt 1/3
#   Attempt 1 failed: Reference missing
#   Attempt 2/3
#   Attempt 2 failed: Reference missing
#   Attempt 3/3
#   Attempt 3 failed: Reference missing
#   All retries failed for https://pa.newham.gov.uk/online-applications/applicationDetails.do?keyVal=N7478UJYJX000&activeTab=summary, recording NaNs
# Scraping URL 10 of 21: https://pa.newham.gov.uk/online-applications/applicationDetails.do?keyVal=MJCML1JY09F00&activeTab=summary
#   Attempt 1/3
#   Attempt 1 failed: Reference missing
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/Documents/AI4CI/projects/planning_scraper/pipeline/planning_scraper.py:656, in PlanningScraper.scrappy(urls, max_retries)
#     655 if pd.isna(reference):
# --> 656     raise ValueError("Reference missing")
#     658 date_validated = PlanningScraper.get_table_value(driver, "Application Validated")
#
# ValueError: Reference missing
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 data = PlanningScraper.scrappy(urls)
#
# File ~/Documents/AI4CI/projects/planning_scraper/pipeline/planning_scraper.py:690, in PlanningScraper.scrappy(urls, max_retries)
#     688     except Exception as e:
#     689         print(f"  Attempt {attempt} failed: {e}")
# --> 690         time.sleep(random.uniform(10, 30))
#     692 # if all attempts failed, append NaNs for this URL and move on
#     693 if not success:
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame(data)
df
# Out:
#       reference                                                url  \
# 0  23/01098/FUL  https://pa.newham.gov.uk/online-applications/a...
# 1  18/02826/CLE  https://pa.newham.gov.uk/online-applications/a...
# 2  18/00696/LA3  https://pa.newham.gov.uk/online-applications/a...
# 3  16/01386/CLP  https://pa.newham.gov.uk/online-applications/a...
# 4  15/00593/AOD  https://pa.newham.gov.uk/online-applications/a...
# 5  14/02843/AOD  https://pa.newham.gov.uk/online-applications/a...
#
#     date_validated                                            address  \
# 0  Fri 16 Jun 2023  Curwen Primary School Atlas Road Plaistow Lond...
# 1  Thu 04 Oct 2018              11 Atlas Road Plaistow London E13 0AG
# 2  Wed 14 Mar 2018  Curwen Primary School Atlas Road Plaistow Lond...
# 3  Tue 24 May 2016               5 Atlas Road Plaistow London E13 0AG
# 4  Mon 16 Mar 2015  Curwen Junior And Infants School Atlas Road Pl...
# 5  Thu 18 Dec 2014  Curwen Junior And Infants School Atlas Road Pl...
#
#                                          description decision  \
# 0  Proposed erection of a single storey timber ga...  Approve
# 1  Certificate of lawfulness for the existing use...  Approve
# 2  Installation of external canopy to match canop...  Approve
# 3              Proposed single storey rear extension   Refuse
# 4  Approval of details pursuant to Condition 9 (D...  Approve
# 5  Approval of details pursuant to Condition 4 (C...  Approve
#
#      decision_date                                  app type  \
# 0  Fri 25 Aug 2023                  Full Planning Permission
# 1  Thu 29 Nov 2018    Certificate of Lawfulness Existing Use
# 2  Tue 17 Apr 2018  Local Authority Regulation 3 Application
# 3  Tue 19 Jul 2016    Certificate of Lawfulness Proposed Use
# 4  Fri 10 Jul 2015                       Approval of Details
# 5  Thu 29 Jan 2015                       Approval of Details
#
#   actual_decision_level expected_decision_level
# 0    Delegated decision           Not Available
# 1    Delegated decision           Not Available
# 2    Committee decision           Not Available
# 3    Delegated decision           Not Available
# 4   Approval of Details           Not Available
# 5   Approval of Details           Not Available

# %%
len(df)
# Out:
# 6
