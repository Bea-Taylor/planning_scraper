# %% [markdown]
# # Planning Application Scraper - Example Implementation
#
# This notebook demonstrates the refactored planning scraper with:
# - Modular function usage
# - Logging to stdout
# - Address processing with GeoLocater
# - Progress tracking

# %% [markdown]
# ## 1. Setup and Imports

# %%
import pandas as pd
from datetime import datetime

# Import refactored modules
from pipeline import (
    ApplicationScraper,
    get_postcode_page,
    get_logger,
    GeoLocater
)
from pipeline.logger import (
    log_scraping_session,
    log_scraping_progress,
    log_scraping_summary
)
from pipeline.config import Config
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 5
#       2 from datetime import datetime
#       4 # Import refactored modules
# ----> 5 from pipeline import (
#       6     ApplicationScraper,
#       7     get_postcode_page,
#       8     get_logger,
#       9     GeoLocater
#      10 )
#      11 from pipeline.logger import (
#      12     log_scraping_session,
#      13     log_scraping_progress,
#      14     log_scraping_summary
#      15 )
#      16 from pipeline.config import Config
#
# ImportError: cannot import name 'ApplicationScraper' from 'pipeline' (/Users/bea/Documents/AI4CI/projects/planning_scraper/pipeline/__init__.py)

# %% [markdown]
# ## 2. Initialize Logger
#
# The logger writes to stdout with colored output for different log levels.

# %%
# Get logger (writes to stdout)
logger = get_logger("planning_scraper", level="INFO")
logger.info("Planning Scraper initialized successfully!")

# %% [markdown]
# ## 3. Define Example Postcodes

# %%
# Example postcodes for different councils
examples = {
    'newham': 'E13 0AG',
    'southwark': 'SE5 8UH',
    'lambeth': 'SW9 6DE'
}

logger.info(f"Configured {len(examples)} example postcodes")

# %% [markdown]
# ## 4. Check Council Configuration

# %%
# Load council URLs
url_df = pd.read_csv("data/input/example_urls.csv")
print("Available councils:")
display(url_df)

# Get URL for a specific council using Config
newham_url = Config.get_council_url("newham")
logger.info(f"Newham URL: {newham_url}")

# %% [markdown]
# ## 5. Search for Applications by Postcode
#
# Using the refactored `get_postcode_page()` function.

# %%
# Select council and postcode
council = "newham"
postcode = examples[council]

logger.info(f"Searching for applications in {council.upper()}, postcode: {postcode}")

# Search for applications
urls = get_postcode_page(council=council, postcode=postcode)

logger.info(f"Found {len(urls)} application URLs")
print(f"\nFirst 5 URLs:")
for i, url in enumerate(urls[:5], 1):
    print(f"{i}. {url}")

# %% [markdown]
# ## 6. Scrape Application Details
#
# Using the `ApplicationScraper` class with automatic retries and progress logging.

# %%
# Initialize scraper
scraper = ApplicationScraper(
    os_type="mac",  # Change to "linux" if needed
    max_retries=3
)

# For demo, scrape only first 10 URLs (change to scrape all)
urls_to_scrape = urls[:10]

logger.info(f"Scraping {len(urls_to_scrape)} applications...")

# %%
# Log session start
start_time = datetime.now()
log_scraping_session(
    logger=logger,
    council=council,
    total_urls=len(urls_to_scrape),
    start_time=start_time
)

# Scrape applications
data = scraper.scrape_app_details(urls_to_scrape)

# Log summary
duration = (datetime.now() - start_time).total_seconds()
success_count = sum(1 for ref in data['reference'] if pd.notna(ref))
failed_count = len(urls_to_scrape) - success_count

log_scraping_summary(
    logger=logger,
    total=len(urls_to_scrape),
    success=success_count,
    failed=failed_count,
    duration_seconds=duration
)

# %% [markdown]
# ## 7. Create and Inspect DataFrame

# %%
# Convert to DataFrame
df = pd.DataFrame(data)

logger.info(f"Created DataFrame with {len(df)} rows and {len(df.columns)} columns")

# Display first few rows
print("\nScraped Applications:")
display(df.head())

# %%
# Show summary statistics
print("\n📊 Summary Statistics:")
print(f"Total applications: {len(df)}")
print(f"Unique references: {df['reference'].nunique()}")
print(f"Date range: {df['date_validated'].min()} to {df['date_validated'].max()}")
print(f"\nDecision breakdown:")
print(df['decision'].value_counts())

# %% [markdown]
# ## 8. Process Addresses with GeoLocater
#
# Extract postcodes and clean addresses using the new GeoLocater module.

# %%
logger.info("Processing addresses...")

# Process addresses in DataFrame
df = GeoLocater.process_address_dataframe(df, address_column='address')

# Show new columns
print("\n📍 Processed Address Data:")
display(df[['reference', 'address', 'postcode', 'cleaned_address']].head())

# %%
# Postcode statistics
valid_postcodes = df['postcode'].notna().sum()
logger.info(f"Extracted {valid_postcodes}/{len(df)} valid postcodes")

print("\n📮 Unique Postcodes Found:")
print(df['postcode'].value_counts().head(10))

# %% [markdown]
# ## 9. Extract Individual Postcodes
#
# Demonstrate individual address processing.

# %%
# Example: Extract postcode from individual address
if len(df) > 0:
    sample_address = df['address'].iloc[0]
    
    print(f"Original Address: {sample_address}")
    
    # Extract postcode
    postcode_extracted = GeoLocater.extract_postcode(sample_address)
    print(f"Extracted Postcode: {postcode_extracted}")
    
    # Clean address
    cleaned = GeoLocater.clean_address(sample_address)
    print(f"Cleaned Address: {cleaned}")
    
    # Parse address
    parsed = GeoLocater.parse_address(sample_address)
    print(f"\nParsed Components:")
    print(f"  Street: {parsed.street}")
    print(f"  City: {parsed.city}")
    print(f"  Postcode: {parsed.postcode}")

# %% [markdown]
# ## 10. Filter and Analyze Data

# %%
# Filter by specific postcode
target_postcode = examples[council]

df_filtered = df[df['postcode'] == target_postcode]

logger.info(f"Found {len(df_filtered)} applications with postcode {target_postcode}")
print(f"\nApplications at {target_postcode}:")
display(df_filtered[['reference', 'address', 'decision', 'decision_date']])

# %%
# Analyze decisions by application type
if 'app type' in df.columns:
    decision_by_type = pd.crosstab(
        df['app type'],
        df['decision'],
        margins=True
    )
    
    print("\n📋 Decisions by Application Type:")
    display(decision_by_type)

# %% [markdown]
# ## 11. Save Results

# %%
# Save to CSV
output_file = f"data/output/{council}_applications_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
df.to_csv(output_file, index=False)

logger.info(f"Saved {len(df)} applications to {output_file}")
print(f"\n💾 Results saved to: {output_file}")

# %% [markdown]
# ## 12. Summary

# %%
print("\n" + "="*70)
print("SCRAPING COMPLETE!")
print("="*70)
print(f"Council: {council.upper()}")
print(f"Postcode: {postcode}")
print(f"Total URLs found: {len(urls)}")
print(f"Applications scraped: {len(df)}")
print(f"Valid postcodes extracted: {valid_postcodes}")
print(f"Success rate: {success_count/len(urls_to_scrape)*100:.1f}%")
print(f"Duration: {duration:.1f} seconds")
print(f"Output file: {output_file}")
print("="*70)

# %% [markdown]
# ## 13. Advanced: Address Deduplication (Optional)

# %%
# Get list of all addresses
all_addresses = df['address'].dropna().tolist()

# Deduplicate
unique_addresses = GeoLocater.deduplicate_addresses(all_addresses)

print(f"\n🏠 Address Deduplication:")
print(f"Original addresses: {len(all_addresses)}")
print(f"Unique addresses: {len(unique_addresses)}")
print(f"Duplicates removed: {len(all_addresses) - len(unique_addresses)}")

# %% [markdown]
# ## Next Steps
#
# 1. **Scrape more councils**: Change the `council` variable to try other councils
# 2. **Scrape all URLs**: Remove the slice `[:10]` to scrape all applications
# 3. **Add geocoding**: Integrate with Postcodes.io API in `geo_locater.py`
# 4. **Export to different formats**: Try JSON or Parquet instead of CSV
# 5. **Analyze patterns**: Create visualizations of decisions by area
#
# See `example_advanced.py` for more examples!
